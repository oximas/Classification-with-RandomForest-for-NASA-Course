# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay
from sklearn.preprocessing import OneHotEncoder

# %%
#Loading the data
data = pd.read_csv(r"/kaggle/input/star-type-classification/Stars.csv")
print("Shape:",data.shape)
print(data.head())
# Out:
# Shape: (240, 7)
#    Temperature         L       R    A_M Color Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12   Red              M     0
# 1         3042  0.000500  0.1542  16.60   Red              M     0
# 2         2600  0.000300  0.1020  18.70   Red              M     0
# 3         2800  0.000200  0.1600  16.65   Red              M     0
# 4         1939  0.000138  0.1030  20.06   Red              M     0

# %%
X = data.drop(columns=["Type"])
y = data["Type"]

# %%
#Split the data intro Train and test
#1) YOUR CODE GOES HERE:

# %%
# Define encoder
encoder = OneHotEncoder(handle_unknown="ignore")  # ignore unknown categories in test set

# Select categorical columns
categorical_cols = ["Color", "Spectral_Class"]

# Fit on train and transform both
X_train_encoded = encoder.fit_transform(X_train[categorical_cols])
X_test_encoded = encoder.transform(X_test[categorical_cols])

# Get encoded column names
encoded_cols = encoder.get_feature_names_out(categorical_cols)

# Convert to DataFrame
X_train_encoded = pd.DataFrame(X_train_encoded.toarray(), columns=encoded_cols, index=X_train.index)
X_test_encoded = pd.DataFrame(X_test_encoded.toarray(), columns=encoded_cols, index=X_test.index)

# Optionally concatenate with other numeric features
X_train = pd.concat([X_train.drop(columns=categorical_cols), X_train_encoded], axis=1)
X_test = pd.concat([X_test.drop(columns=categorical_cols), X_test_encoded], axis=1)

# %%
# Train model (use RandomForest to train a model)
#2) YOUR CODE GOES HERE:

# %%
#Print the accuracy score
#3) YOUR CODE GOES HERE:

# %%
#display the confusion matrix
#4) YOUR CODE GOES HERE:
